# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Hands-on Lab : Web Scraping**

# %% [markdown]
# Estimated time needed: **30 to 45** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Extract information from a given web site
# *   Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site
#
# You will extract the data from the below web site: <br>

# %%
import sys
sys.path.append("/Users/felip/anaconda3/pkgs/Lib/site-packages")

# %%
print(sys.path)
# Out:
# ['c:\\Users\\felip\\python_work\\IBM_Data_Analyst_Specialization\\6_Capstone_project', 'c:\\Users\\felip\\.vscode\\extensions\\ms-toolsai.jupyter-2021.11.1001550889\\pythonFiles', 'c:\\Users\\felip\\.vscode\\extensions\\ms-toolsai.jupyter-2021.11.1001550889\\pythonFiles\\lib\\python', 'C:\\Users\\felip\\anaconda3\\python39.zip', 'C:\\Users\\felip\\anaconda3\\DLLs', 'C:\\Users\\felip\\anaconda3\\lib', 'C:\\Users\\felip\\anaconda3', '', 'C:\\Users\\felip\\anaconda3\\lib\\site-packages', 'C:\\Users\\felip\\anaconda3\\lib\\site-packages\\locket-0.2.1-py3.9.egg', 'C:\\Users\\felip\\anaconda3\\lib\\site-packages\\win32', 'C:\\Users\\felip\\anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\Users\\felip\\anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\Users\\felip\\anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\felip\\.ipython', '/Users/felip/anaconda3/pkgs/Lib/site-packages']

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# The data you need to scrape is the **name of the programming language** and **average annual salary**.<br> It is a good idea to open the url in your web broswer and study the contents of the web page before you start to scrape.

# %% [markdown]
# Import the required libraries

# %%
# !{sys.executable} -m pip install bs4
# Out:
# ...
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1271 sha256=2c503bb9b0e4a7f1bac1bd7ec721dbf76507edafebe4f2eb3bd6b55969e8fcd0
#   Stored in directory: c:\users\felip\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# ...

# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd

# %% [markdown]
# Download the webpage at the url

# %%
data = requests.get(url).text

# %% [markdown]
# Create a soup object

# %%
soup = BeautifulSoup(data,"html.parser")

# %% [markdown]
# Scrape the `Language name` and `annual average salary`.

# %%
table = soup.find('table')

# %%
popular_language =[]
for row in table.find_all('tr'):
    cols = row.find_all('td')
    language_name = cols[1].getText()
    ann_avg_salary = cols[3].getText()
    print("{}--->{}".format(language_name, ann_avg_salary))
    popular_lan = [language_name,ann_avg_salary]
    popular_language.append(popular_lan)

print(popular_language)
# Out:
# Language--->Average Annual Salary
# Python--->$114,383
# Java--->$101,013
# R--->$92,037
# Javascript--->$110,981
# Swift--->$130,801
# C++--->$113,865
# C#--->$88,726
# PHP--->$84,727
# SQL--->$84,793
# Go--->$94,082
# [['Language', 'Average Annual Salary'], ['Python', '$114,383'], ['Java', '$101,013'], ['R', '$92,037'], ['Javascript', '$110,981'], ['Swift', '$130,801'], ['C++', '$113,865'], ['C#', '$88,726'], ['PHP', '$84,727'], ['SQL', '$84,793'], ['Go', '$94,082']]

# %% [markdown]
# Save the scrapped data into a file named *popular-languages.csv*

# %%
with open('popular-languages.csv','w',newline='') as file:
    csvwriter = csv.writer(file)
    for row in popular_language:
        csvwriter.writerow(row)

# %%
df = pd.DataFrame(popular_language, columns = ['Language', 'Average Annual Salary'])
df = df.drop(0, axis=0)
df
# Out:
#       Language Average Annual Salary
# 1       Python              $114,383
# 2         Java              $101,013
# 3            R               $92,037
# 4   Javascript              $110,981
# 5        Swift              $130,801
# 6          C++              $113,865
# 7           C#               $88,726
# 8          PHP               $84,727
# 9          SQL               $84,793
# 10          Go               $94,082

# %%
df
# Out:
#       Language Average Annual Salary
# 1       Python              $114,383
# 2         Java              $101,013
# 3            R               $92,037
# 4   Javascript              $110,981
# 5        Swift              $130,801
# 6          C++              $113,865
# 7           C#               $88,726
# 8          PHP               $84,727
# 9          SQL               $84,793
# 10          Go               $94,082

# %%
df.to_csv('popular-languages.csv')

# %%
df.to_excel('popular-languages.xlsx')

# %%
file = open('popular-languages.csv', 'a')

try:
    file.write(f"{language_name},{ann_avg_salary}")

finally:
    file.close()

# %%
import numpy as np
import pandas as pd
import csv

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01).
